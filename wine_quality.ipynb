# %%
# import libaray 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r"C:\Users\CHETAN\OneDrive\Desktop\winequality-red.csv")
df.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6      0.069
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
# 5                 13.0                  40.0   0.9978  3.51       0.56
# 6                 15.0                  59.0   0.9964  3.30       0.46
# 7                 15.0                  21.0   0.9946  3.39       0.47
# 8                  9.0                  18.0   0.9968  3.36       0.57
# 9                 17.0                 102.0   0.9978  3.35       0.80
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5
# 5      9.4        5
# 6      9.4        5
# 7     10.0        7
# 8      9.5        7
# 9     10.5        5

# %%
df.tail(10)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1589            6.6             0.725         0.20             7.8      0.073
# 1590            6.3             0.550         0.15             1.8      0.077
# 1591            5.4             0.740         0.09             1.7      0.089
# 1592            6.3             0.510         0.13             2.3      0.076
# 1593            6.8             0.620         0.08             1.9      0.068
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1589                 29.0                  79.0  0.99770  3.29       0.54
# 1590                 26.0                  35.0  0.99314  3.32       0.82
# 1591                 16.0                  26.0  0.99402  3.67       0.56
# 1592                 29.0                  40.0  0.99574  3.42       0.75
# 1593                 28.0                  38.0  0.99651  3.42       0.82
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 1589      9.2        5
# 1590     11.6        6
# 1591     11.6        6
# 1592     11.0        6
# 1593      9.5        6
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6

# %%
#consider 6 no. or higher is good quality and reaminaing is less than is not good 
Q = []
for i in df['quality']:
    if i >=6:
        i= 'good'
        Q.append(i)
    else:
        i='not good'
        Q.append(i)

# %%
# added list data to dataframe 
df['Quality'] = Q
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality   Quality
# 0         9.4        5  not good
# 1         9.8        5  not good
# 2         9.8        5  not good
# 3         9.8        6      good
# 4         9.4        5  not good
# ...       ...      ...       ...
# 1594     10.5        5  not good
# 1595     11.2        6      good
# 1596     11.0        6      good
# 1597     10.2        5  not good
# 1598     11.0        6      good
#
# [1599 rows x 13 columns]

# %%
# replaced quality data good is 1 and not good is 0
df['Quality'] = df['Quality'].replace({'good':1,'not good':0})
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality  Quality
# 0         9.4        5        0
# 1         9.8        5        0
# 2         9.8        5        0
# 3         9.8        6        1
# 4         9.4        5        0
# ...       ...      ...      ...
# 1594     10.5        5        0
# 1595     11.2        6        1
# 1596     11.0        6        1
# 1597     10.2        5        0
# 1598     11.0        6        1
#
# [1599 rows x 13 columns]

# %%
# check label count and data is balanced 
df['Quality'].value_counts()
# Out:
# 1    855
# 0    744
# Name: Quality, dtype: int64

# %%
# drop the quality data in default in data beacause we add new quality data  
df.drop('quality',axis=1,inplace=True)

# %%
# checking information 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  Quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %% [markdown]
# no null present in feature and not present object value

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %% [markdown]
# another proof is non null present in data using heatmap

# %%
for i in df.columns:
    x = df[i].value_counts()
    print(x)
# Out:
# 7.2     67
# 7.1     57
# 7.8     53
# 7.5     52
# 7.0     50
#         ..
# 13.5     1
# 13.8     1
# 13.4     1
# 4.7      1
# 5.5      1
# Name: fixed acidity, Length: 96, dtype: int64
# 0.600    47
# 0.500    46
# 0.430    43
# 0.590    39
# 0.360    38
#          ..
# 1.035     1
# 0.565     1
# 1.130     1
# 1.115     1
# 1.090     1
# Name: volatile acidity, Length: 143, dtype: int64
# 0.00    132
# 0.49     68
# 0.24     51
# 0.02     50
# 0.26     38
#        ...
# 0.72      1
# 0.62      1
# 0.75      1
# 1.00      1
# 0.78      1
# Name: citric acid, Length: 80, dtype: int64
# 2.00     156
# 2.20     131
# 1.80     129
# 2.10     128
# 1.90     117
#         ...
# 4.25       1
# 2.85       1
# 3.45       1
# 2.35       1
# 13.90      1
# Name: residual sugar, Length: 91, dtype: int64
# 0.080    66
# 0.074    55
# 0.076    51
# 0.078    51
# 0.084    49
#          ..
# 0.108     1
# 0.148     1
# 0.143     1
# 0.222     1
# 0.230     1
# Name: chlorides, Length: 153, dtype: int64
# 6.0     138
# 5.0     104
# 10.0     79
# 15.0     78
# 12.0     75
# 7.0      71
# 9.0      62
# 16.0     61
# 17.0     60
# 11.0     59
# 13.0     57
# 8.0      56
# 14.0     50
# 3.0      49
# 18.0     46
# 4.0      41
# 21.0     41
# 19.0     39
# 24.0     34
# 26.0     32
# 23.0     32
# 20.0     30
# 27.0     29
# 25.0     24
# 29.0     23
# 28.0     23
# 22.0     22
# 32.0     22
# 31.0     20
# 34.0     18
# 30.0     16
# 35.0     15
# 36.0     11
# 33.0     11
# 38.0      9
# 41.0      7
# 40.0      6
# 39.0      5
# 48.0      4
# 51.0      4
# 45.0      3
# 1.0       3
# 43.0      3
# 42.0      3
# 52.0      3
# 37.0      3
# 68.0      2
# 55.0      2
# 50.0      2
# 37.5      2
# 53.0      1
# 72.0      1
# 57.0      1
# 47.0      1
# 5.5       1
# 2.0       1
# 46.0      1
# 54.0      1
# 40.5      1
# 66.0      1
# Name: free sulfur dioxide, dtype: int64
# 28.0     43
# 24.0     36
# 15.0     35
# 18.0     35
# 23.0     34
#          ..
# 139.0     1
# 149.0     1
# 152.0     1
# 155.0     1
# 165.0     1
# Name: total sulfur dioxide, Length: 144, dtype: int64
# 0.99720    36
# 0.99680    35
# 0.99760    35
# 0.99800    29
# 0.99620    28
#            ..
# 0.99684     1
# 0.99764     1
# 0.99473     1
# 0.99320     1
# 0.99651     1
# Name: density, Length: 436, dtype: int64
# 3.30    57
# 3.36    56
# 3.26    53
# 3.38    48
# 3.39    48
#         ..
# 3.75     1
# 2.74     1
# 3.70     1
# 3.85     1
# 2.90     1
# Name: pH, Length: 89, dtype: int64
# 0.60    69
# 0.58    68
# 0.54    68
# 0.62    61
# 0.56    60
#         ..
# 1.00     1
# 1.59     1
# 0.33     1
# 1.26     1
# 1.01     1
# Name: sulphates, Length: 96, dtype: int64
# 9.500000     139
# 9.400000     103
# 9.800000      78
# 9.200000      72
# 10.000000     67
#             ...
# 9.950000       1
# 9.233333       1
# 9.250000       1
# 9.050000       1
# 10.750000      1
# Name: alcohol, Length: 65, dtype: int64
# 1    855
# 0    744
# Name: Quality, dtype: int64

# %% [markdown]
# check value count method for all column and see no null , no white space value is present in data and check unique values

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996750
# 75%       0.090000            21.000000             62.000000     0.997835
# max       0.611000            72.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      Quality
# count  1599.000000  1599.000000  1599.000000  1599.000000
# mean      3.311113     0.658149    10.422983     0.534709
# std       0.154386     0.169507     1.065668     0.498950
# min       2.740000     0.330000     8.400000     0.000000
# 25%       3.210000     0.550000     9.500000     0.000000
# 50%       3.310000     0.620000    10.200000     1.000000
# 75%       3.400000     0.730000    11.100000     1.000000
# max       4.010000     2.000000    14.900000     1.000000

# %% [markdown]
# 1)fixed acidity is right skewness present and also present outlier
#
# 2)volatile acidity and citric acid is normal bell curve distribution
#
# 3)residual sugar is right skewness present and also diffrance 75% and max valve outlier present
#
# 4)chlorides is right skewness present and aslo diffrance 75 % and max valve outler present
#
# 5)free sulfur dioxide is right skewness present and  diffrance 75% and max valve outlier present
#
# 6)total sulfur dioxide is right skewness present and diffrance 75% and max valve oulter present
#
# 7)sulphates is right skewness present and diffrance 75 % and max valve outlier present

# %%
plt.figure(figsize=(30,25))
plotnumber = 1

for i in df:
    if plotnumber<=12:
        plt.subplot(3,4,plotnumber)
        sns.distplot(df[i])
        plt.xlabel(i,fontsize=20)
    plotnumber+=1 
plt.show()

# %% [markdown]
# check using distplot how data is distributed
#
# 1) volatile acidity, alcohol, citric acid is look like minimum right skewness and outlier
#
# 2) residual sugar, chlorides, free sulfur dioxide, total sulfur dioxide, sulphates is high right skewness and higher outler
#
# 3) fixed acidity, density, pH is look like normal distribution

# %%
# check skewness
df.skew()
# Out:
# fixed acidity           0.982751
# volatile acidity        0.671593
# citric acid             0.318337
# residual sugar          4.540655
# chlorides               5.680347
# free sulfur dioxide     1.250567
# total sulfur dioxide    1.515531
# density                 0.071288
# pH                      0.193683
# sulphates               2.428672
# alcohol                 0.860829
# Quality                -0.139303
# dtype: float64

# %% [markdown]
# also check using df.skew method how data present skewness
# we considerd  in range -0.5 and 0.5 not present skewness

# %%
# check outlier using boxplot
plt.figure(figsize=(30,25))
pltn = 1

for b in df:
    if pltn<=12:
        plt.subplot(3,4,pltn)
        sns.boxplot(df[b])
        plt.xlabel(b,fontsize=20)
    pltn+=1
plt.show()

# %% [markdown]
# outlier present in all feature except citric acid
#
# drop outlier using zscore method

# %%
from scipy import stats 
from scipy.stats import zscore

# %%
# we consider 60% data.
z_score = zscore(df)
abs_zscore = np.abs(z_score)
entery = (abs_zscore<2).all(axis=1)
df = df[entery]
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1124.000000       1124.000000  1124.000000     1124.000000
# mean        8.163078          0.518283     0.247589        2.264724
# std         1.365514          0.155680     0.177490        0.615027
# min         5.200000          0.180000     0.000000        1.200000
# 25%         7.200000          0.398750     0.090000        1.900000
# 50%         7.800000          0.520000     0.240000        2.100000
# 75%         9.000000          0.630000     0.390000        2.500000
# max        11.800000          0.885000     0.660000        5.200000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1124.000000          1124.000000           1124.000000  1124.000000
# mean      0.080899            14.591637             40.755338     0.996645
# std       0.017886             8.327425             24.493584     0.001448
# min       0.038000             1.000000              6.000000     0.993060
# 25%       0.071000             8.000000             22.000000     0.995648
# 50%       0.079000            13.000000             35.000000     0.996640
# 75%       0.088250            20.000000             54.000000     0.997505
# max       0.178000            36.000000            112.000000     1.000400
#
#                pH    sulphates      alcohol      Quality
# count  1124.00000  1124.000000  1124.000000  1124.000000
# mean      3.32113     0.632438    10.309638     0.546263
# std       0.12357     0.117353     0.903107     0.498077
# min       3.02000     0.330000     8.500000     0.000000
# 25%       3.23000     0.550000     9.500000     0.000000
# 50%       3.32000     0.610000    10.100000     1.000000
# 75%       3.40000     0.700000    11.000000     1.000000
# max       3.61000     0.990000    12.500000     1.000000

# %%
df.shape
# Out:
# (1124, 12)

# %%
# after apply zscore we check skewness using df.skew method 
df.skew()
# Out:
# fixed acidity           0.645585
# volatile acidity        0.087962
# citric acid             0.269797
# residual sugar          1.762143
# chlorides               1.464467
# free sulfur dioxide     0.660757
# total sulfur dioxide    0.875606
# density                 0.132748
# pH                      0.046460
# sulphates               0.668888
# alcohol                 0.604173
# Quality                -0.186099
# dtype: float64

# %%
# check also using distplot how data is distributed 
plt.figure(figsize=(30,25))
plotnumber = 1

for i in df:
    if plotnumber<=11:
        plt.subplot(3,4,plotnumber)
        sns.distplot(df[i])
        plt.xlabel(i,fontsize=20)
    plotnumber+=1
plt.show()

# %%
# seprate the feature and label 
x = df.drop('Quality',axis=1)
y = df['Quality']

# %%
# check feature vs label realation 
plt.figure(figsize=(30,25))
plotnumber = 1

for i in df:
    if plotnumber<=12:
        plt.subplot(3,4,plotnumber)
        sns.stripplot(x=y,y=df[i],hue=y)
        plt.xlabel(i,fontsize=20)
    plotnumber+=1
plt.tight_layout()

# %%
plt.figure(figsize=(30,25))
plotnumber = 1

for i in df:
    if plotnumber<=12:
        plt.subplot(3,4,plotnumber)
        sns.barplot(x=y,y=df[i],hue=y)
        plt.xlabel(i,fontsize=20)
    plotnumber+=1
plt.tight_layout()

# %%
plt.figure(figsize=(30,25))
plotnumber = 1

for i in df:
    if plotnumber<=12:
        plt.subplot(3,4,plotnumber)
        sns.lineplot(x=y,y=df[i])
        plt.xlabel(i,fontsize=20)
    plotnumber+=1
plt.tight_layout()

# %%
x.shape
# Out:
# (1124, 11)

# %%
y.value_counts()
# Out:
# 1    614
# 0    510
# Name: Quality, dtype: int64

# %%
# check correlation with corrwith 
x.corrwith(y)
# Out:
# fixed acidity           0.132982
# volatile acidity       -0.299624
# citric acid             0.195416
# residual sugar          0.035491
# chlorides              -0.105983
# free sulfur dioxide    -0.027967
# total sulfur dioxide   -0.195747
# density                -0.147832
# pH                     -0.048088
# sulphates               0.379541
# alcohol                 0.455544
# dtype: float64

# %%
# visulaize the correlation with label 
x.corrwith(y).plot(kind='bar',grid=True,figsize=(8,5),title='correlation with label')
plt.show()

# %% [markdown]
# sulphates and alchol is strongly possitve reation with label
#
# volatile acidity is strongly negative relation with label

# %%
# visualze using heat map and check multicolineary problem 
plt.figure(figsize=(20,15))
sns.heatmap(df.corr(),linewidths=0.1,annot=True)
plt.yticks(rotation=0)
plt.show()

# %% [markdown]
# residual sugar, free sulfur dioxide and ph feature is less contribute to label

# %%
from sklearn.preprocessing import StandardScaler   
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
scaled = StandardScaler()
Scaled = pd.DataFrame(scaled.fit_transform(x),columns=x.columns)
Scaled
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0         -0.559070          1.167766    -1.395566       -0.593286  -0.274053
# 1         -0.266010          2.324497    -1.395566        0.545383   0.956524
# 2         -0.266010          1.553343    -1.170101        0.057382   0.620912
# 3          2.225004         -1.531274     1.760944       -0.593286  -0.329989
# 4         -0.559070          1.167766    -1.395566       -0.593286  -0.274053
# ...             ...               ...          ...             ...        ...
# 1119      -0.998661          0.653663    -0.944636       -0.593286  -0.721536
# 1120      -1.438251          0.525137    -0.944636       -0.430619   0.509041
# 1121      -1.364986         -0.053228    -0.662805        0.057382  -0.274053
# 1122      -1.658046          0.814320    -0.719171       -0.430619  -0.329989
# 1123      -1.584781         -1.338485     1.253648        2.172052  -0.777471
#
#       free sulfur dioxide  total sulfur dioxide   density        pH  \
# 0               -0.431494             -0.275923  0.797740  1.529128
# 1                1.250446              1.071968  0.106912 -0.980691
# 2                0.049060              0.540981  0.245078 -0.494919
# 3                0.289337              0.786052  0.935906 -1.304538
# 4               -0.431494             -0.275923  0.797740  1.529128
# ...                   ...                   ...       ...       ...
# 1119             1.610862             -0.112542 -0.093428  0.800471
# 1120             2.091416              0.132529 -1.205661  1.043357
# 1121             1.731001             -0.030852 -0.625365  0.800471
# 1122             2.091416              0.132529 -0.811889  2.014900
# 1123             0.409476              0.050838 -0.798072  0.557585
#
#       sulphates   alcohol
# 0     -0.617537 -1.007680
# 1      0.405472 -0.564568
# 2      0.149720 -0.564568
# 3     -0.447035 -0.564568
# 4     -0.617537 -1.007680
# ...         ...       ...
# 1119   1.598982 -0.896902
# 1120  -0.447035  0.210879
# 1121   1.002227  0.764770
# 1122   0.661224 -0.121455
# 1123   0.234970  0.764770
#
# [1124 rows x 11 columns]

# %%
# finding variance inflaction factor for each column
vif = []
for i in range(Scaled.shape[1]):
    X = variance_inflation_factor(Scaled,i)
    vif.append(X)

# %%
VIF = pd.DataFrame()
VIF['vif'] = vif 
VIF['feature'] = x.columns
VIF
# Out:
#          vif               feature
# 0   5.837637         fixed acidity
# 1   2.080742      volatile acidity
# 2   3.051853           citric acid
# 3   1.547523        residual sugar
# 4   1.160321             chlorides
# 5   1.955368   free sulfur dioxide
# 6   2.238156  total sulfur dioxide
# 7   4.931980               density
# 8   2.721232                    pH
# 9   1.315635             sulphates
# 10  3.024787               alcohol

# %% [markdown]
# consider vif >= 5
#
# fixed acidity and density have multicolinearity problem

# %%
# consider fixed acidity feature to drop beacuse more vif value is present 
Scaled = Scaled.drop('fixed acidity',axis=1)

# %%
v = []
for i in range(Scaled.shape[1]):
    V = variance_inflation_factor(Scaled,i)
    v.append(V)

# %%
Vif = pd.DataFrame()
Vif['vif'] = v 
Vif['feature'] = Scaled.columns
Vif
# Out:
#         vif               feature
# 0  2.078450      volatile acidity
# 1  2.764512           citric acid
# 2  1.420213        residual sugar
# 3  1.158088             chlorides
# 4  1.947547   free sulfur dioxide
# 5  2.187380  total sulfur dioxide
# 6  2.362732               density
# 7  1.320002                    pH
# 8  1.314151             sulphates
# 9  2.285933               alcohol

# %% [markdown]
# data have no multicolinearity problem

# %%
# check data is imblaced or not 
y.value_counts()
# Out:
# 1    614
# 0    510
# Name: Quality, dtype: int64

# %%
sns.countplot(data=df,x='Quality')
plt.show()

# %%
# split the data for train and test 
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25,random_state=155)

# %%
# build logitc regression model 
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
LR = LogisticRegression()
LR.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = LR.predict(x_test)
# model accuracy

# %%
print(accuracy_score(y_test,y_pred))

print(confusion_matrix(y_test,y_pred))

print(classification_report(y_test,y_pred))
# Out:
# 0.7188612099644128
# [[ 88  30]
#  [ 49 114]]
#               precision    recall  f1-score   support
#
#            0       0.64      0.75      0.69       118
#            1       0.79      0.70      0.74       163
#
#     accuracy                           0.72       281
#    macro avg       0.72      0.72      0.72       281
# weighted avg       0.73      0.72      0.72       281

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
gbdt = GradientBoostingClassifier()
gbdt.fit(x_train,y_train)
# Out:
# GradientBoostingClassifier()

# %%
y = gbdt.predict(x_test)
print(classification_report(y_test,y))
print(accuracy_score(y_test,y))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.73      0.70       118
#            1       0.79      0.74      0.76       163
#
#     accuracy                           0.73       281
#    macro avg       0.73      0.73      0.73       281
# weighted avg       0.74      0.73      0.73       281
#
# 0.7330960854092526

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
# initiate kneighbourclassifer

knn = KNeighborsClassifier()

# model training 
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
A = knn.predict(x_test)
print(classification_report(y_test,A))
print(accuracy_score(y_test,A))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.50      0.55      0.53       118
#            1       0.65      0.61      0.63       163
#
#     accuracy                           0.58       281
#    macro avg       0.58      0.58      0.58       281
# weighted avg       0.59      0.58      0.59       281
#
# 0.5836298932384342

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,roc_curve,roc_auc_score
from sklearn.tree import DecisionTreeClassifier

# %%
dt = DecisionTreeClassifier()
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
DT =dt.predict(x_test)
print(accuracy_score(y_test,DT))
print(confusion_matrix(y_test,DT))
print(classification_report(y_test,DT))
# Out:
# 0.7366548042704626
# [[ 80  38]
#  [ 36 127]]
#               precision    recall  f1-score   support
#
#            0       0.69      0.68      0.68       118
#            1       0.77      0.78      0.77       163
#
#     accuracy                           0.74       281
#    macro avg       0.73      0.73      0.73       281
# weighted avg       0.74      0.74      0.74       281

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
RFC = RandomForestClassifier()
RFC.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
rfc = RFC.predict(x_test)
print(accuracy_score(y_test,rfc))
print(confusion_matrix(y_test,rfc))
print(classification_report(y_test,rfc))
# Out:
# 0.7758007117437722
# [[ 90  28]
#  [ 35 128]]
#               precision    recall  f1-score   support
#
#            0       0.72      0.76      0.74       118
#            1       0.82      0.79      0.80       163
#
#     accuracy                           0.78       281
#    macro avg       0.77      0.77      0.77       281
# weighted avg       0.78      0.78      0.78       281

# %%
from sklearn.svm import SVC

# %%
svc = SVC()
svc.fit(x_train,y_train)
# Out:
# SVC()

# %%
SVC = svc.predict(x_test)
print(accuracy_score(y_test,SVC))
print(confusion_matrix(y_test,SVC))
print(classification_report(y_test,SVC))
# Out:
# 0.6298932384341637
# [[ 42  76]
#  [ 28 135]]
#               precision    recall  f1-score   support
#
#            0       0.60      0.36      0.45       118
#            1       0.64      0.83      0.72       163
#
#     accuracy                           0.63       281
#    macro avg       0.62      0.59      0.58       281
# weighted avg       0.62      0.63      0.61       281

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
ada = AdaBoostClassifier()
ada.fit(x_train,y_train)
# Out:
# AdaBoostClassifier()

# %%
Ada = ada.predict(x_test)
print(accuracy_score(y_test,Ada))
print(confusion_matrix(y_test,Ada))
print(classification_report(y_test,Ada))
# Out:
# 0.7188612099644128
# [[ 87  31]
#  [ 48 115]]
#               precision    recall  f1-score   support
#
#            0       0.64      0.74      0.69       118
#            1       0.79      0.71      0.74       163
#
#     accuracy                           0.72       281
#    macro avg       0.72      0.72      0.72       281
# weighted avg       0.73      0.72      0.72       281

# %%
from sklearn.ensemble import BaggingClassifier

# %%
bag = BaggingClassifier()
bag.fit(x_train,y_train)
# Out:
# BaggingClassifier()

# %%
Bag = bag.predict(x_test)
print(accuracy_score(y_test,Bag))
print(confusion_matrix(y_test,Bag))
print(classification_report(y_test,Bag))
# Out:
# 0.7686832740213523
# [[ 99  19]
#  [ 46 117]]
#               precision    recall  f1-score   support
#
#            0       0.68      0.84      0.75       118
#            1       0.86      0.72      0.78       163
#
#     accuracy                           0.77       281
#    macro avg       0.77      0.78      0.77       281
# weighted avg       0.79      0.77      0.77       281

# %%
from sklearn.model_selection import cross_val_score

# %%
score = cross_val_score(LR,x_train,y_train,cv=10)
print(score)
print(score.mean())
print(accuracy_score(y_test,y_pred) - score.mean())
# Out:
# [0.72941176 0.71764706 0.76470588 0.75       0.77380952 0.72619048
#  0.77380952 0.71428571 0.76190476 0.6547619 ]
# 0.7366526610644258
# -0.01779145110001301

# %%
gbdt_score = cross_val_score(gbdt,x_train,y_train,cv=10)
print(gbdt_score)
print(gbdt_score.mean())
print(accuracy_score(y_test,y) - gbdt_score.mean())
# Out:
# [0.72941176 0.74117647 0.76470588 0.77380952 0.82142857 0.72619048
#  0.76190476 0.82142857 0.82142857 0.79761905]
# 0.7759103641456582
# -0.04281427873640553

# %%
knn_score = cross_val_score(knn,x_train,y_train,cv=10)
print(knn_score)
print(knn_score.mean())
print(accuracy_score(y_test,A) - knn_score.mean())
# Out:
# [0.56470588 0.6        0.74117647 0.66666667 0.52380952 0.5952381
#  0.57142857 0.73809524 0.60714286 0.66666667]
# 0.6274929971988795
# -0.04386310396044535

# %%
dt_score = cross_val_score(dt,x_train,y_train,cv=10)
print(dt_score)
print(dt_score.mean())
print(accuracy_score(y_test,DT) - dt_score.mean())
# Out:
# [0.64705882 0.70588235 0.67058824 0.75       0.73809524 0.76190476
#  0.75       0.71428571 0.73809524 0.78571429]
# 0.7261624649859943
# 0.010492339284468244

# %%
RFC_score = cross_val_score(RFC,x_train,y_train,cv=10)
print(RFC_score)
print(RFC_score.mean())
print(accuracy_score(y_test,rfc) - RFC_score.mean())
# Out:
# [0.76470588 0.75294118 0.82352941 0.78571429 0.88095238 0.77380952
#  0.78571429 0.79761905 0.8452381  0.80952381]
# 0.8019747899159665
# -0.026174078172194304

# %%
svc_score = cross_val_score(svc,x_train,y_train,cv=10)
print(svc_score)
print(svc_score.mean())
print(accuracy_score(y_test,SVC) - svc_score.mean())
# Out:
# [0.64705882 0.6        0.61176471 0.61904762 0.57142857 0.5952381
#  0.64285714 0.64285714 0.55952381 0.54761905]
# 0.6037394957983193
# 0.026153742635844357

# %%
ada_score = cross_val_score(ada,x_train,y_train,cv=10)
print(ada_score)
print(ada_score.mean())
print(accuracy_score(y_test,Ada) - ada_score.mean())
# Out:
# [0.74117647 0.70588235 0.74117647 0.75       0.79761905 0.67857143
#  0.76190476 0.70238095 0.70238095 0.66666667]
# 0.7247759103641458
# -0.005914700399732964

# %%
bag_score = cross_val_score(bag,x_train,y_train,cv=10)
print(bag_score)
print(bag_score.mean())
print(accuracy_score(y_test,Bag) - bag_score.mean())
# Out:
# [0.67058824 0.72941176 0.78823529 0.77380952 0.85714286 0.77380952
#  0.72619048 0.80952381 0.75       0.78571429]
# 0.7664425770308123
# 0.00224069699053997

# %% [markdown]
# the best model is adaboostClassifier
#
# apply hyperparameter tuning in adaboostClassifier model to increase accuracy

# %%
Ada = AdaBoostClassifier()

ada.fit(x_train,y_train)
# Out:
# AdaBoostClassifier()

# %%
from sklearn.model_selection import GridSearchCV

# %%
params = {'n_estimators':range(1,100,5),'learning_rate':np.arange(0.001,0.1,0.01)}

# %%
grd_ada = GridSearchCV(AdaBoostClassifier(),param_grid=params)

# %%
grd_ada.fit(x_train,y_train)
# Out:
# GridSearchCV(estimator=AdaBoostClassifier(),
#              param_grid={'learning_rate': array([0.001, 0.011, 0.021, 0.031, 0.041, 0.051, 0.061, 0.071, 0.081,
#        0.091]),
#                          'n_estimators': range(1, 100, 5)})

# %%
grd_ada.best_estimator_
# Out:
# AdaBoostClassifier(learning_rate=0.09099999999999998, n_estimators=91)

# %%
 Ada = AdaBoostClassifier(learning_rate=0.09099999999999998,n_estimators=91)

ada.fit(x_train,y_train)
# Out:
# AdaBoostClassifier()

# %%
ADA = ada.predict(x_test)
print(accuracy_score(y_test,ADA))
print(confusion_matrix(y_test,ADA))
print(classification_report(y_test,ADA))
# Out:
# 0.7188612099644128
# [[ 87  31]
#  [ 48 115]]
#               precision    recall  f1-score   support
#
#            0       0.64      0.74      0.69       118
#            1       0.79      0.71      0.74       163
#
#     accuracy                           0.72       281
#    macro avg       0.72      0.72      0.72       281
# weighted avg       0.73      0.72      0.72       281

# %% [markdown]
# plot ROc curve for AdaBoostClassifier

# %%
from sklearn import metrics

# %%
fpr,tpr,threshold = metrics.roc_curve(y_test,ADA)
roc_auc = metrics.auc(fpr,tpr)
display = metrics.RocCurveDisplay(fpr=fpr,tpr=tpr,roc_auc=roc_auc,estimator_name=Ada)
display.plot()

# %% [markdown]
# AdaboostClassifier AUC score is 72%
