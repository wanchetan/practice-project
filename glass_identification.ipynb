# %%
# import lib
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r"C:\Users\CHETAN\OneDrive\Desktop\practice_project\Glass Identification.csv")
df.head()
# Out:
#    1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.00.1  1.1
# 0  2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83   0.0    0.00    1
# 1  3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78   0.0    0.00    1
# 2  4  1.51766  13.21  3.69  1.29  72.61  0.57  8.22   0.0    0.00    1
# 3  5  1.51742  13.27  3.62  1.24  73.08  0.55  8.07   0.0    0.00    1
# 4  6  1.51596  12.79  3.61  1.62  72.97  0.64  8.07   0.0    0.26    1

# %%
# set index name for understanding 
df.set_axis(['Id number','RI refractive index','Na: Sodium','Mg: Magnesium','Al: Aluminum','Si: Silicon','K: Potassium','Ca: Calcium',
             'Ba: Barium','Fe: Iron','Type of glass'],axis=1,inplace=True)

# %%
df
# Out:
#      Id number  RI refractive index  Na: Sodium  Mg: Magnesium  Al: Aluminum  \
# 0            2              1.51761       13.89           3.60          1.36
# 1            3              1.51618       13.53           3.55          1.54
# 2            4              1.51766       13.21           3.69          1.29
# 3            5              1.51742       13.27           3.62          1.24
# 4            6              1.51596       12.79           3.61          1.62
# ..         ...                  ...         ...            ...           ...
# 208        210              1.51623       14.14           0.00          2.88
# 209        211              1.51685       14.92           0.00          1.99
# 210        212              1.52065       14.36           0.00          2.02
# 211        213              1.51651       14.38           0.00          1.94
# 212        214              1.51711       14.23           0.00          2.08
#
# ...

# %%
# divideing glass types if type of glass is euqal to or less than 4 than he window glass otherwise non window glass 
w = []
for i in df['Type of glass']:
    if i <=4:
        i = 'window glass'
        w.append(i)
    else:
        i = 'non-window glass'
        w.append(i)

# %%
df['type of glass'] = w
df
# Out:
#      Id number  RI refractive index  Na: Sodium  Mg: Magnesium  Al: Aluminum  \
# 0            2              1.51761       13.89           3.60          1.36
# 1            3              1.51618       13.53           3.55          1.54
# 2            4              1.51766       13.21           3.69          1.29
# 3            5              1.51742       13.27           3.62          1.24
# 4            6              1.51596       12.79           3.61          1.62
# ..         ...                  ...         ...            ...           ...
# 208        210              1.51623       14.14           0.00          2.88
# 209        211              1.51685       14.92           0.00          1.99
# 210        212              1.52065       14.36           0.00          2.02
# 211        213              1.51651       14.38           0.00          1.94
# 212        214              1.51711       14.23           0.00          2.08
#
# ...

# %%
# drop orignal label 
df.drop('Type of glass',axis=1,inplace=True)

# %%
# replace window glass with 1 and non window glass 0 
df['type of glass'] = df['type of glass'].replace({'window glass':1,'non-window glass':0})
df
# Out:
#      Id number  RI refractive index  Na: Sodium  Mg: Magnesium  Al: Aluminum  \
# 0            2              1.51761       13.89           3.60          1.36
# 1            3              1.51618       13.53           3.55          1.54
# 2            4              1.51766       13.21           3.69          1.29
# 3            5              1.51742       13.27           3.62          1.24
# 4            6              1.51596       12.79           3.61          1.62
# ..         ...                  ...         ...            ...           ...
# 208        210              1.51623       14.14           0.00          2.88
# 209        211              1.51685       14.92           0.00          1.99
# 210        212              1.52065       14.36           0.00          2.02
# 211        213              1.51651       14.38           0.00          1.94
# 212        214              1.51711       14.23           0.00          2.08
#
# ...

# %%
df['type of glass'].value_counts()
# Out:
# 1    162
# 0     51
# Name: type of glass, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 213 entries, 0 to 212
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id number            213 non-null    int64
#  1   RI refractive index  213 non-null    float64
#  2   Na: Sodium           213 non-null    float64
#  3   Mg: Magnesium        213 non-null    float64
#  4   Al: Aluminum         213 non-null    float64
#  5   Si: Silicon          213 non-null    float64
#  6   K: Potassium         213 non-null    float64
#  7   Ca: Calcium          213 non-null    float64
#  8   Ba: Barium           213 non-null    float64
#  9   Fe: Iron             213 non-null    float64
#  10  type of glass        213 non-null    int64
# dtypes: float64(9), int64(2)
# memory usage: 18.4 KB

# %% [markdown]
# null value not present in data

# %%
# drop id number feature 
df.drop('Id number',axis=1,inplace=True)

# %%
df['RI refractive index'].value_counts()
# Out:
# 1.52152    3
# 1.51590    3
# 1.51645    3
# 1.51761    2
# 1.51613    2
#           ..
# 1.51625    1
# 1.51569    1
# 1.51605    1
# 1.51588    1
# 1.51651    1
# Name: RI refractive index, Length: 177, dtype: int64

# %%
df['Na: Sodium'].value_counts()
# Out:
# 13.21    5
# 13.02    5
# 13.00    5
# 12.85    4
# 12.86    4
#         ..
# 13.34    1
# 13.31    1
# 14.17    1
# 13.51    1
# 14.23    1
# Name: Na: Sodium, Length: 142, dtype: int64

# %%
df['Mg: Magnesium'].value_counts()
# Out:
# 0.00    42
# 3.48     8
# 3.58     8
# 3.54     8
# 3.52     7
#         ..
# 3.46     1
# 3.73     1
# 3.97     1
# 3.89     1
# 1.78     1
# Name: Mg: Magnesium, Length: 93, dtype: int64

# %%
df['Al: Aluminum'].value_counts()
# Out:
# 1.54    8
# 1.19    6
# 1.56    5
# 1.29    5
# 1.43    5
#        ..
# 1.61    1
# 0.88    1
# 1.05    1
# 0.65    1
# 1.94    1
# Name: Al: Aluminum, Length: 117, dtype: int64

# %%
df['Si: Silicon'].value_counts()
# Out:
# 72.99    4
# 73.10    4
# 72.86    4
# 73.28    4
# 73.11    4
#         ..
# 70.57    1
# 73.81    1
# 72.92    1
# 73.55    1
# 73.61    1
# Name: Si: Silicon, Length: 132, dtype: int64

# %%
df['K: Potassium'].value_counts()
# Out:
# 0.00    30
# 0.57    12
# 0.56    11
# 0.60    11
# 0.58    10
#         ..
# 0.44     1
# 0.07     1
# 0.73     1
# 0.70     1
# 1.41     1
# Name: K: Potassium, Length: 65, dtype: int64

# %%
df['Ca: Calcium'].value_counts()
# Out:
# 8.03    5
# 8.43    5
# 8.44    4
# 9.57    4
# 8.79    4
#        ..
# 8.90    1
# 9.13    1
# 7.78    1
# 8.96    1
# 8.62    1
# Name: Ca: Calcium, Length: 143, dtype: int64

# %%
df['Ba: Barium'].value_counts()
# Out:
# 0.00    175
# 0.64      2
# 1.57      2
# 0.09      2
# 1.59      2
# 0.11      2
# 3.15      1
# 0.81      1
# 1.64      1
# 1.06      1
# 0.54      1
# 2.88      1
# 1.38      1
# 1.55      1
# 0.67      1
# 1.71      1
# 0.56      1
# 0.63      1
# 0.53      1
# 0.66      1
# 0.61      1
# 0.27      1
# 0.69      1
# 0.40      1
# 0.14      1
# 0.76      1
# 1.68      1
# 1.63      1
# 1.19      1
# 0.24      1
# 2.20      1
# 0.15      1
# 0.06      1
# 1.67      1
# Name: Ba: Barium, dtype: int64

# %%
df['Fe: Iron'].value_counts()
# Out:
# 0.00    143
# 0.24      7
# 0.17      7
# 0.09      6
# 0.10      5
# 0.11      4
# 0.16      3
# 0.28      3
# 0.12      3
# 0.22      3
# 0.14      3
# 0.07      3
# 0.19      2
# 0.15      2
# 0.08      2
# 0.06      1
# 0.21      1
# 0.05      1
# 0.51      1
# 0.37      1
# 0.35      1
# 0.25      1
# 0.18      1
# 0.34      1
# 0.29      1
# 0.30      1
# 0.20      1
# 0.32      1
# 0.26      1
# 0.03      1
# 0.31      1
# 0.01      1
# Name: Fe: Iron, dtype: int64

# %%
df['type of glass'].value_counts()
# Out:
# 1    162
# 0     51
# Name: type of glass, dtype: int64

# %%
df.describe()
# Out:
#        RI refractive index  Na: Sodium  Mg: Magnesium  Al: Aluminum  \
# count           213.000000  213.000000     213.000000    213.000000
# mean              1.518353   13.406761       2.676056      1.446526
# std               0.003039    0.818371       1.440453      0.499882
# min               1.511150   10.730000       0.000000      0.290000
# 25%               1.516520   12.900000       2.090000      1.190000
# 50%               1.517680   13.300000       3.480000      1.360000
# 75%               1.519150   13.830000       3.600000      1.630000
# max               1.533930   17.380000       3.980000      3.500000
#
#        Si: Silicon  K: Potassium  Ca: Calcium  Ba: Barium    Fe: Iron  \
# count   213.000000    213.000000   213.000000  213.000000  213.000000
# mean     72.655023      0.499108     8.957934    0.175869    0.057277
# std       0.774052      0.653035     1.426435    0.498245    0.097589
# min      69.810000      0.000000     5.430000    0.000000    0.000000
# ...

# %% [markdown]
# 1 ) RI refractive, Na: Sodium, Al: Aluminum, Ca: Calcium, Ba: Barium, Fe: Iron is right skewness present
#
# 2)  Mg: Magnesium, Si: Silicon, K: Potassium,  is left skewness present

# %%
plt.figure(figsize=(30,25))
plot = 1

for i in df:
    if plot<=10:
        plt.subplot(3,4,plot)
        sns.distplot(df[i])
        plt.xlabel(i,fontsize=20)
    plot+=1 
plt.show()

# %%
# check skewness value
df.skew()
# Out:
# RI refractive index    1.639658
# Na: Sodium             0.457318
# Mg: Magnesium         -1.154323
# Al: Aluminum           0.900017
# Si: Silicon           -0.744546
# K: Potassium           6.549276
# Ca: Calcium            2.040591
# Ba: Barium             3.406749
# Fe: Iron               1.747173
# type of glass         -1.229860
# dtype: float64

# %%
plt.figure(figsize=(30,25))
plotnumber = 1

for i in df:
    if plotnumber<=10:
        plt.subplot(4,3,plotnumber)
        sns.boxplot(df[i])
        plt.xlabel(i,fontsize=20)
    plotnumber+=1
plt.show()

# %% [markdown]
# consider outlier beacause data is less

# %%
# using powertransformer keep outler in normalized form
from sklearn.preprocessing import PowerTransformer
pt = PowerTransformer(method='yeo-johnson')

# %%
df['RI refractive index'] = pt.fit_transform(df[['RI refractive index']])
df['Na: Sodium'] = pt.fit_transform(df[['Na: Sodium']])
df['Al: Aluminum'] = pt.fit_transform(df[['Al: Aluminum']])
df['Si: Silicon'] = pt.fit_transform(df[['Si: Silicon']])
df['K: Potassium'] = pt.fit_transform(df[['K: Potassium']])
df['Ca: Calcium'] = pt.fit_transform(df[['Ca: Calcium']])
df['Ba: Barium'] = pt.fit_transform(df[['Ba: Barium']])
df['Fe: Iron'] = pt.fit_transform(df[['Fe: Iron']])

# %%
plt.figure(figsize=(30,25))
plotnumber = 1

for i in df:
    if plotnumber<=10:
        plt.subplot(4,3,plotnumber)
        sns.distplot(df[i])
        plt.xlabel(i,fontsize=20)
    plotnumber+=1
plt.show()

# %%
df.skew()
# Out:
# RI refractive index    0.000000
# Na: Sodium            -0.009526
# Mg: Magnesium         -1.154323
# Al: Aluminum           0.000874
# Si: Silicon            0.133867
# K: Potassium          -0.075233
# Ca: Calcium           -0.207808
# Ba: Barium             1.817526
# Fe: Iron               0.852473
# type of glass         -1.229860
# dtype: float64

# %%
# seprate feature and label 
x = df.drop('type of glass',axis=1)
y = df['type of glass']

# %%
# check correlation feature and label
x.corrwith(y)
# Out:
# RI refractive index    0.135010
# Na: Sodium            -0.432725
# Mg: Magnesium          0.758357
# Al: Aluminum          -0.537209
# Si: Silicon           -0.184815
# K: Potassium           0.298375
# Ca: Calcium            0.005991
# Ba: Barium            -0.602063
# Fe: Iron               0.236674
# dtype: float64

# %% [markdown]
# Ca : Calcium is leass contribute to label

# %%
x.corrwith(y).plot(kind='bar',grid=True)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(20,15))
sns.heatmap(df.corr(),annot=True)
plt.yticks(rotation=0,fontsize=10)
plt.show()

# %% [markdown]
# ca calcium is less contribute and also multicolinearity problem with reaflactive index

# %%
# check variance inflation factor value for check multicolinearity problem
from sklearn.preprocessing import StandardScaler
from statsmodels.stats.outliers_influence import variance_inflation_factor
scaler = StandardScaler()

# %%
scaled =pd.DataFrame(scaler.fit_transform(x),columns=x.columns)

# %%
vif = []
for i in range(scaled.shape[1]):
    x = variance_inflation_factor(scaled,i)
    vif.append(x)

# %%
Vif = pd.DataFrame()
Vif['VIF'] = vif
Vif['Feature'] = x.columns
Vif
# Out:
#         VIF              Feature
# 0  6.357864  RI refractive index
# 1  3.638438           Na: Sodium
# 2  4.003417        Mg: Magnesium
# 3  3.364983         Al: Aluminum
# 4  3.378878          Si: Silicon
# 5  4.022696         K: Potassium
# 6  6.364206          Ca: Calcium
# 7  2.803315           Ba: Barium
# 8  1.091944             Fe: Iron

# %% [markdown]
# vif score of Ca: Calcium is more delect the feature and check again vif score

# %%
scaled.drop('Ca: Calcium',axis=1,inplace=True)

# %%
v = []
for i in range(scaled.shape[1]):
    x = variance_inflation_factor(scaled,i)
    v.append(x)

# %%
vif = pd.DataFrame()
vif['VIF'] = v
vif
# Out:
#         VIF
# 0  5.237343
# 1  2.812390
# 2  2.936426
# 3  3.364962
# 4  3.366216
# 5  2.622275
# 6  2.131897
# 7  1.069128

# %%
scaled
# Out:
#      RI refractive index  Na: Sodium  Mg: Magnesium  Al: Aluminum  \
# 0              -0.229755    0.616990       0.642937     -0.081445
# 1              -0.704878    0.184792       0.608144      0.286720
# 2              -0.229755   -0.210310       0.705564     -0.232162
# 3              -0.308942   -0.135420       0.656854     -0.342629
# 4              -0.784065   -0.745389       0.649895      0.442150
# ..                   ...         ...            ...           ...
# 208            -0.704878    0.909819      -1.862164      2.415518
# 209            -0.506910    1.787436      -1.862164      1.104938
# 210             0.799680    1.162750      -1.862164      1.155073
# 211            -0.586097    1.185528      -1.862164      1.020265
# 212            -0.427723    1.013820      -1.862164      1.253886
#
#      Si: Silicon  K: Potassium  Ba: Barium  Fe: Iron
# 0       0.038252      0.268575   -0.456097 -0.682180
# 1       0.394607      0.011888   -0.456097 -0.682180
# ...

# %%
plt.figure(figsize=(30,25))
pl = 1

for i in scaled:
    if pl<=8:
        plt.subplot(4,4,pl)
        sns.distplot(scaled[i])
        plt.xlabel(i,fontsize=20)
    pl+=1
plt.show()

# %%
plt.figure(figsize=(30,25))
pl = 1

for i in scaled:
    if pl<=8:
        plt.subplot(4,4,pl)
        sns.scatterplot(x=y,y=i,data=scaled)
        plt.xlabel(i,fontsize=20)
    pl+=1
plt.show()

# %%
plt.figure(figsize=(30,25))
pl = 1

for i in scaled:
    if pl<=8:
        plt.subplot(4,3,pl)
        sns.barplot(x=y,y=i, hue=y,data=scaled)
        plt.xlabel(i,fontsize=20)
    pl+=1
plt.show()

# %%
plt.figure(figsize=(30,25))
pl = 1

for i in scaled:
    if pl<=8:
        plt.subplot(4,3,pl)
        sns.histplot(x=y,y=i, hue=y,data=scaled)
        plt.xlabel(i,fontsize=20)
    pl+=1
plt.show()

# %%
plt.figure(figsize=(30,25))
pl = 1

for i in scaled:
    if pl<=8:
        plt.subplot(4,3,pl)
        sns.stripplot(x=y,y=i, hue=y,data=scaled)
        plt.xlabel(i,fontsize=20)
    pl+=1
plt.show()

# %%
sns.countplot(data=df,x=y)
# Out:
# <Axes: xlabel='type of glass', ylabel='count'>

# %% [markdown]
# data is imblanced by check countplot
# for balancing data use oversample mehtod

# %%
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
from collections import Counter

# %%
x_train,x_test,y_train,y_test = train_test_split(scaled,y,test_size=0.30,random_state=155)

# %%
Counter(y_train)
# Out:
# Counter({0: 31, 1: 118})

# %%
smp = SMOTE(random_state=55,k_neighbors=3,sampling_strategy=0.80)
X_train,Y_train = smp.fit_resample(x_train,y_train)
Counter(Y_train)
# Out:
# Counter({0: 94, 1: 118})

# %%
sns.countplot(data=df,x=Y_train)
# Out:
# <Axes: xlabel='type of glass', ylabel='count'>

# %% [markdown]
# now data is balanced we build a model

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingClassifier,RandomForestClassifier,AdaBoostClassifier,BaggingClassifier 
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,roc_curve,roc_auc_score,classification_report
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC 
from sklearn.model_selection import cross_val_score, GridSearchCV, RandomizedSearchCV

# %%
LR = LogisticRegression()
LR.fit(X_train,Y_train)
y_pred = LR.predict(x_test)
print('Accuracy Score :\n',accuracy_score(y_test,y_pred))
print('\n')
print('Confusion Score :\n',confusion_matrix(y_test,y_pred))
print('\n')
print('Classification Report :\n',classification_report(y_test,y_pred))
# Out:
# Accuracy Score :
#  0.921875
#
#
# Confusion Score :
#  [[17  3]
#  [ 2 42]]
#
#
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.89      0.85      0.87        20
#            1       0.93      0.95      0.94        44
#
#     accuracy                           0.92        64
#    macro avg       0.91      0.90      0.91        64
# weighted avg       0.92      0.92      0.92        64

# %%
knn = KNeighborsClassifier()
knn.fit(X_train,Y_train)
knn_pred = knn.predict(x_test)
print('Accuracy Score :\n',accuracy_score(y_test,knn_pred))
print('\n')
print('Confusion Score :\n',confusion_matrix(y_test,knn_pred))
print('\n')
print('Classification Report :\n',classification_report(y_test,knn_pred))
# Out:
# Accuracy Score :
#  0.921875
#
#
# Confusion Score :
#  [[18  2]
#  [ 3 41]]
#
#
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.86      0.90      0.88        20
#            1       0.95      0.93      0.94        44
#
#     accuracy                           0.92        64
#    macro avg       0.91      0.92      0.91        64
# weighted avg       0.92      0.92      0.92        64

# %%
bg = BaggingClassifier()
bg.fit(X_train,Y_train)
bg_pred = bg.predict(x_test)
print('Accuracy Score :\n',accuracy_score(y_test,bg_pred))
print('\n')
print('Confusion Score :\n',confusion_matrix(y_test,bg_pred))
print('\n')
print('Classification Report :\n',classification_report(y_test,bg_pred))
# Out:
# Accuracy Score :
#  0.953125
#
#
# Confusion Score :
#  [[19  1]
#  [ 2 42]]
#
#
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.90      0.95      0.93        20
#            1       0.98      0.95      0.97        44
#
#     accuracy                           0.95        64
#    macro avg       0.94      0.95      0.95        64
# weighted avg       0.95      0.95      0.95        64

# %%
rmf = RandomForestClassifier()
rmf.fit(X_train,Y_train)
rmf_pred = rmf.predict(x_test)
print('Accuracy Score :\n',accuracy_score(y_test,rmf_pred))
print('\n')
print('Confusion Score :\n',confusion_matrix(y_test,rmf_pred))
print('\n')
print('Classification Report :\n',classification_report(y_test,rmf_pred))
# Out:
# Accuracy Score :
#  0.96875
#
#
# Confusion Score :
#  [[20  0]
#  [ 2 42]]
#
#
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95        20
#            1       1.00      0.95      0.98        44
#
#     accuracy                           0.97        64
#    macro avg       0.95      0.98      0.96        64
# weighted avg       0.97      0.97      0.97        64

# %%
ada = AdaBoostClassifier()
ada.fit(X_train,Y_train)
ada_pred = ada.predict(x_test)
print('Accuracy Score :\n',accuracy_score(y_test,ada_pred))
print('\n')
print('Confusion Score :\n',confusion_matrix(y_test,ada_pred))
print('\n')
print('Classification Report :\n',classification_report(y_test,ada_pred))
# Out:
# Accuracy Score :
#  0.96875
#
#
# Confusion Score :
#  [[20  0]
#  [ 2 42]]
#
#
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95        20
#            1       1.00      0.95      0.98        44
#
#     accuracy                           0.97        64
#    macro avg       0.95      0.98      0.96        64
# weighted avg       0.97      0.97      0.97        64

# %%
gbc = GradientBoostingClassifier()
gbc.fit(X_train,Y_train)
gbc_pred = gbc.predict(x_test)
print('Accuracy Score :\n',accuracy_score(y_test,gbc_pred))
print('\n')
print('Confusion Score :\n',confusion_matrix(y_test,gbc_pred))
print('\n')
print('Classification Report :\n',classification_report(y_test,gbc_pred))
# Out:
# Accuracy Score :
#  0.953125
#
#
# Confusion Score :
#  [[19  1]
#  [ 2 42]]
#
#
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.90      0.95      0.93        20
#            1       0.98      0.95      0.97        44
#
#     accuracy                           0.95        64
#    macro avg       0.94      0.95      0.95        64
# weighted avg       0.95      0.95      0.95        64

# %%
dt = DecisionTreeClassifier()
dt.fit(X_train,Y_train)
dt_pred = dt.predict(x_test)
print('Accuracy Score :\n',accuracy_score(y_test,dt_pred))
print('\n')
print('Confusion Score :\n',confusion_matrix(y_test,dt_pred))
print('\n')
print('Classification Report :\n',classification_report(y_test,dt_pred))
# Out:
# Accuracy Score :
#  0.9375
#
#
# Confusion Score :
#  [[18  2]
#  [ 2 42]]
#
#
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.90      0.90      0.90        20
#            1       0.95      0.95      0.95        44
#
#     accuracy                           0.94        64
#    macro avg       0.93      0.93      0.93        64
# weighted avg       0.94      0.94      0.94        64

# %%
svc = SVC()
svc.fit(X_train,Y_train)
svc_pred = svc.predict(x_test)
print('Accuracy Score :\n',accuracy_score(y_test,svc_pred))
print('\n')
print('Confusion Score :\n',confusion_matrix(y_test,svc_pred))
print('\n')
print('Classification Report :\n',classification_report(y_test,svc_pred))
# Out:
# Accuracy Score :
#  0.9375
#
#
# Confusion Score :
#  [[20  0]
#  [ 4 40]]
#
#
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.83      1.00      0.91        20
#            1       1.00      0.91      0.95        44
#
#     accuracy                           0.94        64
#    macro avg       0.92      0.95      0.93        64
# weighted avg       0.95      0.94      0.94        64

# %%
LR_score = cross_val_score(LR,X_train,Y_train,cv=10)
print(LR_score)
print(LR_score.mean())
print(accuracy_score(y_test,y_pred) - LR_score.mean())
# Out:
# [0.90909091 0.90909091 0.9047619  0.95238095 0.95238095 1.
#  0.95238095 0.95238095 1.         0.95238095]
# 0.9484848484848485
# -0.026609848484848486

# %%
bg_score = cross_val_score(bg,X_train,Y_train,cv=10)
print(bg_score)
print(bg_score.mean())
print(accuracy_score(y_test,bg_pred) - bg_score.mean())
# Out:
# [0.90909091 0.95454545 0.85714286 0.95238095 0.95238095 0.95238095
#  0.95238095 1.         0.95238095 1.        ]
# 0.9482683982683981
# 0.004856601731601851

# %%
rmf_score = cross_val_score(rmf,X_train,Y_train,cv=10)
print(rmf_score)
print(rmf_score.mean())
print(accuracy_score(y_test,rmf_pred) - rmf_score.mean())
# Out:
# [0.90909091 0.90909091 0.9047619  0.95238095 0.95238095 1.
#  0.95238095 1.         1.         1.        ]
# 0.958008658008658
# 0.010741341991342024

# %%
gbc_score = cross_val_score(gbc,X_train,Y_train,cv=10)
print(gbc_score)
print(gbc_score.mean())
print(accuracy_score(y_test,gbc_pred) - gbc_score.mean())
# Out:
# [0.90909091 1.         0.85714286 0.95238095 0.95238095 1.
#  0.95238095 1.         1.         1.        ]
# 0.9623376623376624
# -0.00921266233766238

# %%
ada_score = cross_val_score(ada,X_train,Y_train,cv=10)
print(ada_score)
print(ada_score.mean())
print(accuracy_score(y_test,ada_pred) - ada_score.mean())
# Out:
# [0.95454545 0.86363636 0.95238095 1.         0.95238095 0.95238095
#  0.95238095 1.         0.95238095 1.        ]
# 0.958008658008658
# 0.010741341991342024

# %%
knn_score = cross_val_score(knn,X_train,Y_train,cv=10)
print(knn_score)
print(knn_score.mean())
print(accuracy_score(y_test,knn_pred) - knn_score.mean())
# Out:
# [0.81818182 0.90909091 0.85714286 0.9047619  0.9047619  1.
#  0.95238095 1.         0.95238095 0.95238095]
# 0.925108225108225
# -0.0032332251082249908

# %%
dt_score = cross_val_score(dt,X_train,Y_train,cv=10)
print(dt_score)
print(dt_score.mean())
print(accuracy_score(y_test,dt_pred) - dt_score.mean())
# Out:
# [0.90909091 0.95454545 0.85714286 0.95238095 0.95238095 1.
#  0.95238095 1.         1.         1.        ]
# 0.9577922077922079
# -0.02029220779220786

# %%
svc_score = cross_val_score(svc,X_train,Y_train,cv=10)
print(svc_score)
print(svc_score.mean())
print(accuracy_score(y_test,svc_pred) - svc_score.mean())
# Out:
# [0.95454545 0.95454545 0.9047619  1.         0.9047619  1.
#  1.         1.         1.         0.95238095]
# 0.9670995670995671
# -0.029599567099567126

# %% [markdown]
# the best model gradientboostingclassifier
# increase accuracy using hyperparameter tuning

# %%
from sklearn.model_selection import RandomizedSearchCV
 RandomizedSearchCV()
# Out:
#   Cell In[72], line 2
#     RandomizedSearchCV()
#     ^
# IndentationError: unexpected indent

# %%
params = {'n_estimators':range(1,100,10),
          'learning_rate':np.arange(0.001,0.1,0.01),
          'subsample':np.arange(0.001,0.1,0.01), 
          'criterion':['friedman_mse', 'squared_error'],
          'min_samples_split':range(1,10),
          'max_depth':range(1,10),
          'random_state':[100,155,200]}

# %%
GBC = RandomizedSearchCV(GradientBoostingClassifier(),param_distributions=params)
GBC.fit(X_train,Y_train)
# Out:
# RandomizedSearchCV(estimator=GradientBoostingClassifier(),
#                    param_distributions={'criterion': ['friedman_mse',
#                                                       'squared_error'],
#                                         'learning_rate': array([0.001, 0.011, 0.021, 0.031, 0.041, 0.051, 0.061, 0.071, 0.081,
#        0.091]),
#                                         'max_depth': range(1, 10),
#                                         'min_samples_split': range(1, 10),
#                                         'n_estimators': range(1, 100, 10),
#                                         'random_state': [100, 155, 200],
#                                         'subsample': array([0.001, 0.011, 0.021, 0.031, 0.041, 0.051, 0.061, 0.071, 0.081,
#        0.091])})

# %%
GBC.best_estimator_
# Out:
# GradientBoostingClassifier(learning_rate=0.020999999999999998, max_depth=4,
#                            min_samples_split=5, n_estimators=41,
#                            random_state=155, subsample=0.071)

# %%
Gbc = GradientBoostingClassifier(criterion='squared_error', learning_rate=0.071,
                           n_estimators=51, random_state=155,
                           subsample=0.09099999999999998)
Gbc.fit(X_train,Y_train)
Gbc_pred = Gbc.predict(x_test)
print('Accuracy Score :\n',accuracy_score(y_test,Gbc_pred))
print('\n')
print('Confusion Score :\n',confusion_matrix(y_test,Gbc_pred))
print('\n')
print('Classification Report :\n',classification_report(y_test,Gbc_pred))
# Out:
# Accuracy Score :
#  0.953125
#
#
# Confusion Score :
#  [[19  1]
#  [ 2 42]]
#
#
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.90      0.95      0.93        20
#            1       0.98      0.95      0.97        44
#
#     accuracy                           0.95        64
#    macro avg       0.94      0.95      0.95        64
# weighted avg       0.95      0.95      0.95        64

# %%
from sklearn import metrics

# %%
fpr,tpr,threshold = metrics.roc_curve(y_test,Gbc_pred)
roc_auc = metrics.auc(fpr,tpr)
display = metrics.RocCurveDisplay(fpr=fpr,tpr=tpr,roc_auc=roc_auc,estimator_name=Gbc)
display.plot()
